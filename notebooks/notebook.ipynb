# %%
from youtube_transcript_api import YouTubeTranscriptApi
import re

# %%
def extract_video_id(youtube_url):
    """
    Extract the YouTube video ID from a URL.
    Handles various YouTube URL formats.
    """
    video_id_match = re.search(r'(?:v=|\/videos\/|youtu.be\/|\/v\/|\/e\/|\/watch\?v=|&v=|\/embed\/|%2Fvideos%2F|embed%2F|youtu.be%2F|%2Fv%2F|%2Fe%2F|youtube.com\/embed\/|youtube.com\/v\/|youtube.com\/watch\?v=)([^#\&\?\n\/]+)', youtube_url)
    
    if video_id_match:
        return video_id_match.group(1)
    else:
        raise ValueError("Could not extract video ID from URL. Please provide a valid YouTube URL.")

# %%
def get_transcript(youtube_url, output_file=None, language='en'):
    """
    Download transcript from a YouTube video URL.
    
    Args:
        youtube_url (str): The YouTube video URL
        output_file (str, optional): File to save the transcript to. If None, prints to console.
        language (str, optional): Language code for the transcript. Defaults to 'en'.
    
    Returns:
        str: The full transcript text
    """
    try:
        # Extract the video ID from the URL
        video_id = extract_video_id(youtube_url)
        
        # Get the transcript
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=[language])
        
        # Combine all transcript pieces into one text
        transcript_text = ""
        for entry in transcript_list:
            transcript_text += entry['text'] + " "
        
        # Clean up the text
        transcript_text = transcript_text.strip()
        
        # Save to file if specified
        if output_file:
            with open(output_file, 'w', encoding='utf-8') as f:
                f.write(transcript_text)
            print(f"Transcript saved to {output_file}")
        else:
            print(transcript_text)
            
        return transcript_text
    
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
url="https://www.youtube.com/watch?v=ZPUtA3W-7_I"

#url="https://youtu.be/ZPUtA3W-7_I?si=M3RCw7uKRLmD3qhZ"
output="lex.txt"
language="en"
get_transcript(url, output, language)
# Out:
# Transcript saved to lex.txt
# '- My strength lies not in my name, but in the backing of 1.4 billion Indians, and thousands of years of timeless culture\nand heritage. So, wherever I go, I carry with me the\nessence of thousands of years of Vedic tradition, the\ntimeless teachings of Swami Vivekananda, and the blessings, dreams, and aspirations\nof 1.4 billion Indians. When I shake hands with a world leader,\nit\'s not Modi, but 1.4 billion Indians\ndoing so. So, this isn\'t my strength at all. It is\nrather the strength of India. Whenever we speak of peace, the world\nlistens to us. Because India is the land of Gautama\nBuddha and Mahatma Gandhi. And Indians aren\'t hardwired to espouse\nstrife and conflict. We espouse harmony instead. We seek neither to wage war against\nnature, nor to foster strife among\nnations. We stand for peace. And wherever we can act as peacemakers, we\nhave gladly embraced that responsibility. My early life was\nspent in extreme poverty. But we never really felt the burden of\npoverty. You see, someone who is used to wearing\nfine shoes will feel their absence when they don’t\nhave them. But for us, we had never worn shoes in our\nlives, so how would we even know that wearing\nshoes was a big deal? We weren’t in a position to compare. That’s just how we lived. When I became Prime Minister, I specially\ninvited Pakistan to my swearing-in ceremony so we could turn over a new leaf. Yet, every noble attempt at fostering\npeace was met with hostility and betrayal. We sincerely hope that wisdom prevails\nupon them and they choose the path of peace. I believe even the people of Pakistan long\nfor peace. Look, regarding what you said about\ncriticism and how I deal with it, if I had to summarize in one sentence, I\nwelcome it. I have a strong belief that criticism is\nthe soul of democracy. I want to tell all young people the\nfollowing: No matter how dark the night may seem, it is still just night, and morning is\nbound to come. - The following is a\nconversation with Narendra Modi, the Prime Minister of India. It was one of the most moving\nconversations and experiences of my life. Allow me here to say a few words about it. Please skip ahead straight to\nour conversation, if you like. Narendra Modi\'s life story is incredible. He rose from poverty to lead a\nnation of 1.4 billion people, the biggest democracy in the world, where he won epic-scale elections\nfor Prime Minister three times. As a leader, he fought for\nideas that unite his nation of India, a nation that is composed\nof a large number of highly varied and\ndisparate cultures and peoples who have a long history marked by\nreligious, social, and political frictions. He\'s known for taking decisive,\nat times, controversial actions for which he\'s loved by hundreds of millions\nof people, and is also criticized by many. We discuss all of this at\nlength in this conversation. On the world stage,\nhe\'s respected as a peacemaker and friend by most major world leaders, even those\nwhose nations are at war with each other, from United States to China,\nto Ukraine and Russia, to Israel, Palestine, and the Middle East,\nand everywhere else. Now, at this moment in history,\nit\'s clear, at least to me, that the flourishing of human civilization\nhangs in the balance, with several wars on the brink of escalation\nto regional and even global conflict, rising tensions between nuclear powers, technological developments\nfrom AI to nuclear fusion that aim to completely transform\nsociety and geopolitics as we know it, and, of course, generally,\nincreasing political and cultural turmoil. So now more than ever,\nwe need great leaders, great peacemakers, who build\nbridges, not destroy them, who may preserve the\nidentity of their nations, but still celebrate the common\nhumanity of all of us, all people on Earth. For this and many other reasons,\nthis conversation with Prime Minister Modi was one of the most\nremarkable I\'ve ever had. You may hear such words and think\nthat I\'m just ena ...

# %%
import os
import requests
from urllib.parse import urlencode
from PIL import Image
from io import BytesIO

def get_video_title(video_id, api_key):
    if not video_id or not api_key:
        raise ValueError("Invalid video_id or api_key")

    # Construct the API request URL
    base_url = "https://www.googleapis.com/youtube/v3/videos"
    params = {
        "part": "snippet",
        "id": video_id,
        "key": api_key
    }
    url = f"{base_url}?{urlencode(params)}"
    
    try:
        # Send the API request
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad responses
        data = response.json()
        
        # Validate response and extract the video title
        if "items" in data and len(data["items"]) > 0:
            return data["items"][0]["snippet"]["title"]
        else:
            return "Video title not found"
    
    except requests.exceptions.RequestException as e:
        raise requests.RequestException(f"Network or API error: {e}")
    except ValueError as e:
        raise ValueError(f"Error parsing response: {e}")
    except KeyError:
        raise KeyError("Expected data not found in the response")

# %%
def get_video_thumbnail(video_id, api_key, save_path):
    
    if not video_id or not api_key or not save_path:
        print("Invalid parameters provided.")
        return False
    
    # Construct YouTube API request URL
    base_url = "https://www.googleapis.com/youtube/v3/videos"
    params = {
        "part": "snippet",
        "id": video_id,
        "key": api_key
    }
    url = f"{base_url}?{urlencode(params)}"
    
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)
        data = response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching video details: {e}")
        return False
    except ValueError:
        print("Error parsing JSON response.")
        return False

    # Check if the video data exists and extract thumbnail URL
    if "items" in data and len(data["items"]) > 0:
        thumbnail_url = data["items"][0]["snippet"]['thumbnails']['medium']['url']
        return download_image(thumbnail_url, save_path)
    else:
        print("Video not found or no thumbnail available.")
        return False

def download_image(url, save_path):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for non-200 status codes
        img = Image.open(BytesIO(response.content))
        img.verify()
        
        # If the image is valid, save it
        img = Image.open(BytesIO(response.content))  # Reopen the image after verification
        img.save(save_path)
        print(f"Image successfully downloaded and saved to {save_path}")
        return True
    except requests.exceptions.RequestException as e:
        print(f"Error downloading image: {e}")
        return False
    except (IOError, SyntaxError) as e:
        print(f"Error verifying or saving the image: {e}")
        return False

# %%
youtube_url="https://www.youtube.com/watch?v=ZPUtA3W-7_I"
video_id = extract_video_id(youtube_url)
api_key = os.getenv("YOUTUBE_SEARCH_API")
save_path = "./thumbnail.jpg"
get_video_thumbnail(video_id, api_key, save_path)
video_title = get_video_title(video_id, api_key)
video_title
# Out:
# Image successfully downloaded and saved to ./thumbnail.jpg
# 'Narendra Modi: Prime Minister of India - Power, Democracy, War & Peace | Lex Fridman Podcast #460'

# %%
def chunk_text(file_path, chunk_size):
    """
    Reads a text file and splits it into chunks of the specified size.
    
    Args:
        file_path (str): The path to the text file to be read.
        chunk_size (int): The size of each chunk in characters.
        
    Returns:
        list: A list of strings, each representing a chunk of the file's content.
    """
    chunks = []
    with open(file_path, 'r', encoding='utf-8') as file:
        while True:
            # Read a chunk of the specified size
            chunk = file.read(chunk_size*1024)
            if not chunk:
                break
            chunks.append(chunk)
    return chunks

# %%
file_path = 'lex.txt'
chunk_size = 32  # Size of each chunk in kilo bytes
chunks = chunk_text(file_path, chunk_size)
print(len(chunks))

# %%
import ollama

client = ollama.Client()

system_prompt = (
    "As a professional summarizer, create a detailed yet concise summary of the provided text segment.\n\n"
    "Focus on capturing the main ideas and essential information, "
    "eliminating extraneous details, and maintaining clarity and coherence. "
    "Rely strictly on the provided text, without including external information. "
    "Format the summary with subtopics in paragraph form for easy understanding."
)
model = 'llama3.3:latest'

response = client.create(
  model = 'summary-assistant',
  from_ = 'llama3.3:latest',
  system = system_prompt,
  stream = False,
  parameters={"num_ctx": 40*1024, "temperature": 0.1}
)

print(response.status)

# %%
from concurrent.futures import ThreadPoolExecutor

# Define the function to process each chunk
def summarize_chunk(args):
    context, user_prompt = args
    return make_summary(context, user_prompt)

# Assuming 'chunks' is a list of context segments
user_prompt = "As a professional summarizer, create a detailed yet concise summary of the provided Context above."

try:
    with ThreadPoolExecutor(max_workers=20) as executor:
        # Map the summarize_chunk function over the chunks with the user_prompt
        contents = executor.map(summarize_chunk, [(context, user_prompt) for context in chunks])
        
    content_list = [content for content in contents if content['message']['content'] is not None]
except Exception as e:
    print(f"An error occurred: {e}")

print(len(content_list))
content_list

# %%
from multiprocessing import Pool

# Define the function to process each chunk
def summarize_chunk(args):
    context, user_prompt = args
    return make_summary(context, user_prompt)

if __name__ == '__main__':
    # Assuming 'chunks' is a list of context segments
    user_prompt = "As a professional summarizer, create a detailed yet concise summary of the provided Context above."

    # Create a pool of worker processes
    with Pool() as pool:
        # Map the summarize_chunk function over the chunks with the user_prompt
        contents = pool.map(summarize_chunk, [(context, user_prompt) for context in chunks])

    # Filter out any content where 'message' or 'content' is None
    content_list = [content for content in contents if content.get('message', {}).get('content') is not None]

    print(len(content_list))
    print(content_list)

# %% [markdown]
# # Next Steps

# %%
import os

def read_and_concatenate_chunks(directory):
    # Initialize an empty string to hold the concatenated content
    full_content = ""
    
    # List all files in the directory
    files = os.listdir(directory)
    
    # Filter files that start with 'chunk_results_' and end with '.txt'
    chunk_files = [f for f in files if f.startswith('chunk_results_') and f.endswith('.txt')]
    
    # Sort the files based on the numeric part after 'chunk_results_'
    chunk_files.sort(key=lambda x: int(x.split('_')[2].split('.')[0]))
    
    # Iterate over each sorted chunk file
    for index, filename in enumerate(chunk_files, start=1):
        file_path = os.path.join(directory, filename)
        with open(file_path, 'r') as file:
            # Read the content of the file
            content = file.read()
        
        # Create a header for the subcontext
        subcontext_header = f"==== SubContext {index} ======\n"
        
        # Append the header and content to the full_content string
        full_content += subcontext_header + content + "\n"
    
    return full_content

# %%
directory_path = '.'
concatenated_content = read_and_concatenate_chunks(directory_path)
print(concatenated_content)
# Out:
# ==== SubContext 1 ======
# The conversation with Narendra Modi, Prime Minister of India, delves into his life story, leadership philosophy, and spiritual practices. Born in Vadnagar, Gujarat, to a modest family, Modi grew up in extreme poverty but never felt its burden due to his family's resilience and hard work. His father was known for his discipline and early morning routines, while his mother instilled values of service and cleanliness.
#
# Modi’s upbringing was deeply influenced by the rich cultural heritage of Vadnagar, a town with historical significance dating back 2800 years. He recalls his childhood as one filled with curiosity about history and tradition, which later shaped his worldview. Despite living in scarcity, Modi found joy and contentment in simple pleasures and developed habits of neatness and discipline.
#
# Modi’s spiritual journey began early, influenced by the teachings of Swami Vivekananda and other Indian philosophers. At 17, he embarked on a two-year pilgrimage to the Himalayas, where he lived a minimalist existence, often sleeping outdoors without shelter. This period was marked by intense self-exploration and experimentation with physical endurance, such as enduring cold nights without cover.
#
# Modi’s leadership philosophy is rooted in his belief that India's strength lies not just in its leaders but in the collective spirit of 1.4 billion Indians and thousands of years of cultural heritage. He emphasizes peace and harmony, drawing on the legacies of figures like Gautama Buddha and Mahatma Gandhi. Despite facing hostility from neighboring countries, Modi remains committed to fostering peace.
#
# In his role as Prime Minister, Modi has taken decisive actions that have earned him both admiration and criticism. His approach to leadership is characterized by a strong belief in self-discipline and the importance of giving rather than receiving. He encourages young people to persevere through challenges with patience and confidence, emphasizing that there are no shortcuts in life.
#
# Modi’s spiritual practices include fasting for extended periods, which he views as a form of self-discipline and introspection. Fasting enhances his senses and accelerates his thinking process, allowing him to maintain focus and productivity even while abstaining from food. He shares anecdotes about how world leaders have reacted with curiosity and admiration towards his ability to fast during important meetings.
#
# Modi’s advice for young people is to cultivate a mindset of continuous learning and service. Instead of focusing on becoming someone or achieving something, he suggests dreaming of doing something meaningful. This approach fosters resilience and contentment, as achievements are seen as steps toward larger goals rather than ends in themselves.
#
# Overall, the conversation highlights Modi's journey from humble beginnings to leading India’s largest democracy, emphasizing his commitment to peace, self-discipline, and service. His leadership philosophy is deeply intertwined with spiritual practices and a strong sense of cultural identity, which he believes are essential for guiding India into the future.
# ==== SubContext 2 ======
# The narrative revolves around Narendra Modi's spiritual journey, his political development, and his approach to leadership and diplomacy. Early in life, he formed a deep bond with Swami Atmasthananda Ji, who guided him towards service rather than monasticism. This guidance was pivotal as it steered Modi away from taking sanyasa (renunciation) and instead led him toward a life of public service.
#
# Modi's spiritual journey included wandering through the Himalayas where he practiced meditation and served others, which strengthened his inner resolve and commitment to service. He also spent time with various saints who instilled in him a sense of purpose and dedication to serving society. This spiritual foundation was complemented by his involvement with the Rashtriya Swayamsevak Sangh (RSS), an organization that emphasized discipline, purposeful action, and national service.
#
# The RSS played a significant role in shaping Modi's political ideology through its emphasis on nationalism and community service. It instilled values such as serving the nation through every activity one undertakes, whether it is studying or exercising. The RSS also inspired numerous social initiatives like Seva Bharati, which runs thousands of community projects, and Vidya Bharati, an educational organization that has established nearly 25,000 schools.
#
# Modi's vision for India is rooted in its cultural unity despite vast linguistic and regional diversity. He believes the idea of India transcends administrative systems and lies in its cultural bonds, exemplified by shared traditions like pilgrimage and rituals that connect people across regions. This cultural identity has been a unifying force throughout history, preserving national unity even during periods of fragmented governance.
#
# Mahatma Gandhi's influence on Modi is profound; he admires Gandhi’s dedication to service, his principles of cleanliness, and his ability to mobilize the masses for India’s independence struggle. Gandhi’s approach to weaving every task into the fabric of freedom inspired Modi to include the common man in all aspects of national development.
#
# In terms of international relations, Modi emphasizes a balance between being respected and feared on the global stage. He believes that India's strength lies not just in his leadership but in the collective power of its 1.4 billion people and its rich cultural heritage. His foreign policy is guided by principles of mutual respect and global well-being, as seen in initiatives like "One Earth, One Family, One Future" and "One Sun, One World, One Grid."
#
# Modi's approach to peacemaking involves leveraging India’s historical legacy of peace (as the land of Buddha and Gandhi) to mediate conflicts. He has attempted to improve relations with Pakistan through diplomatic gestures but remains disappointed by recurring tensions. Sports like cricket and football play a role in fostering better relations, as they bring people together across national boundaries.
#
# Modi's recent visit to the United States reinvigorated his friendship with Donald Trump, whom he respects for his courage and dedication to America. Their bond is characterized by mutual trust and respect, exemplified during events like "Howdy Modi" where Trump walked among thousands of supporters without hesitation.
#
# Overall, Modi’s leadership style blends spiritual grounding, national service, cultural unity, and a commitment to global peace and well-being. His vision for India emphasizes its rich heritage while striving towards modernization and international cooperation.
# ==== SubContext 3 ======
# The provided context offers insights into interactions between Narendra Modi, Prime Minister of India, and various political figures, including Donald Trump, Xi Jinping, and Elon Musk. It also delves into critical aspects of governance, elections, and personal philosophies.
#
# ### Relationship with Donald Trump
#
# Modi describes his relationship with former U.S. President Donald Trump as one marked by mutual respect and trust. Despite not meeting physically for years after Trump's first term ended in 2021, their communication remained strong through indirect means. Modi notes that Trump referred to him as a friend on multiple occasions, highlighting the enduring nature of their relationship.
#
# Trump’s recent comments about Modi being an excellent negotiator are acknowledged by Modi with humility and gratitude. He emphasizes his commitment to India's interests in every negotiation, ensuring that no one takes offense due to his straightforward approach.
#
# ### Meetings with Other Figures
#
# During a visit to the United States, Modi met several influential individuals including Elon Musk, JD Vance, Tulsi Gabbard, and Vivek Ramaswamy. These meetings were characterized by warm atmospheres and family-like settings. Discussions ranged from Musk's Doge mission to broader economic and technological advancements.
#
# ### Governance and Reforms
#
# Modi details significant reforms implemented since his tenure began in 2014. He highlights the removal of over a hundred million fake or duplicate names from government welfare schemes, saving nearly ₹3 trillion through Direct Benefit Transfer (DBT). This initiative eliminated middlemen and ensured transparency. Additionally, he introduced the Government e-Marketplace (GeM) portal for government purchases, enhancing competition and quality while reducing unnecessary compliances.
#
# ### Relationship with China
#
# Modi discusses his friendship with Chinese President Xi Jinping and the importance of maintaining strong ties between India and China. He emphasizes that despite recent tensions, both nations share a deep cultural connection and should focus on dialogue to resolve disputes rather than conflict. The 2020 border incidents are noted as a significant challenge, but efforts have been made to restore normalcy.
#
# ### Global Peace
#
# In the context of global conflicts, Modi advocates for cooperation over competition and highlights the interdependence of nations in today's world. He stresses that international organizations like the UN must fulfill their roles effectively to prevent further fragmentation and conflict.
#
# ### 2002 Gujarat Riots
#
# Modi reflects on his tenure as Chief Minister during the 2002 Gujarat riots, which were marked by significant violence between Hindu and Muslim communities. Despite criticism and allegations, he underscores that the judiciary found him innocent in two separate trials. He attributes the post-riot peace to a shift from appeasement politics to one of aspiration and development.
#
# ### Dealing with Criticism
#
# Modi welcomes genuine criticism as essential for democracy but differentiates it from baseless allegations. He believes that well-informed, specific criticism is crucial for effective policy-making and governance.
#
# ### Winning Elections
#
# Winning elections in India, the world's largest democracy, requires a deep sense of duty and trust-building with citizens. Modi emphasizes his commitment to ensuring welfare schemes reach every citizen without discrimination. His party’s extensive network of volunteers plays a significant role in mobilizing support across diverse demographics.
#
# ### Election Logistics
#
# The logistics involved in conducting free and fair elections in India are immense. With over 980 million registered voters, the country ensures that no voter is more than two kilometers away from a polling station. This includes setting up remote polling stations using helicopters and other means to reach even the most isolated areas.
#
# ### Power and Loneliness
#
# Modi views his role not as one of power but as service to the people and nation. He does not feel lonely, attributing this to his spiritual beliefs and constant engagement with work and community members.
#
# ### Work Ethic
#
# His philosophy on hard work is inspired by observing others' dedication, such as farmers, soldiers, laborers, and family caregivers. Modi vows never to fall behind in hard work for the country, act with bad intentions, or do anything for personal gain.
#
# ### Inspiration from Ramanujan
#
# Modi expresses deep respect for Srinivasa Ramanujan, a self-taught mathematician who overcame poverty to become one of the greatest mathematicians. This admiration reflects Modi's own journey and commitment to serving India with dedication and perseverance.
#
# This summary encapsulates the multifaceted aspects of Modi’s governance, personal philosophy, and international relations as discussed in the provided context.
# ==== SubContext 4 ======
# The provided context delves into several key aspects of leadership, decision-making, spirituality, education, and technology, as articulated by Prime Minister Narendra Modi in an interview or conversation.
#
# **Spirituality and Science Connection**
# Prime Minister Modi emphasizes the deep connection between science and spirituality. He cites Srinivasa Ramanujan's belief that his mathematical ideas came from a spiritual source, highlighting how discipline and devotion are integral to achieving great scientific breakthroughs. Knowledge is distinguished from mere information; it evolves through reflection and understanding.
#
# **Decision-Making Process**
# Modi describes his decision-making process as multifaceted:
# 1. **Ground-Level Experience**: He has extensive firsthand knowledge of grassroots issues across India.
# 2. **No Baggage**: His decisions are free from personal biases or historical constraints.
# 3. **Country First**: Decisions are guided by the principle that they should not harm the nation.
# 4. **Gandhian Wisdom**: Considering how actions affect the poorest citizens ensures ethical decision-making.
# 5. **Well-Connected Network**: He receives insights from various sources, maintaining a learner's mindset and challenging perspectives to ensure thorough analysis.
#
# **Handling Crisis: COVID Response**
# During the pandemic, Modi resisted global pressures to spend excessively or print more currency. Instead, he focused on ensuring that no one went hungry and maintained social stability. This approach led India to avoid severe inflation post-COVID and emerge as a rapidly growing economy.
#
# **AI Leadership in India**
# Modi believes India is essential for AI development due to its vast pool of talented engineers and the unique cultural values that foster collaboration, ethical behavior, and problem-solving abilities. He highlights India's cost-effective approach to space missions like Chandrayaan, which has garnered global respect for Indian talent.
#
# **Human Intelligence vs. AI**
# Modi argues that while technology advances, humans adapt and stay ahead by leveraging their creativity and imagination. Human intelligence remains irreplaceable due to its boundless creativity and the ability to care for others.
#
# **Education System and Exam Stress**
# The education system in India is under scrutiny for creating undue stress on students through exam rankings. Modi advocates for a shift towards actual learning rather than rote memorization, emphasizing innovative teaching methods that engage children naturally with numbers and concepts. He also discusses his "Pariksha Pe Charcha" initiative to interact directly with students and address their concerns.
#
# **Advice to Students**
# Modi advises students to focus on enhancing skills and finding purpose in their work, regardless of the field they choose. Success comes from dedication and sincerity, and he encourages a growth mindset that values continuous learning and improvement.
#
# **Mortality and Hope for the Future**
# Regarding mortality, Modi believes there is no point fearing death since it is inevitable. Instead, one should embrace life fully and with purpose. He expresses optimism about human civilization's resilience and adaptability to overcome crises and evolve positively.
#
# **Spirituality and Meditation**
# Modi shares his spiritual practices, including chanting mantras like the Gayatri Mantra for enlightenment and peace. He describes meditation as a simple practice of being present in the moment, free from distractions, which he learned through practical techniques such as focusing on rhythmic sounds.
#
# Overall, Prime Minister Modi's insights highlight the importance of integrating spirituality with scientific advancement, fostering an education system that values learning over exams, making decisions based on ethical principles and national well-being, and embracing technology while valuing human creativity and resilience.
# ==== SubContext 5 ======
# The provided context discusses various aspects of human interaction, travel experiences in India, and reflections on literature, particularly focusing on Herman Hesse's novel "Siddhartha."
#
# **Human Interaction and Reading People**
# Reading people can be challenging due to protective layers that shield their true selves from the outside world. The author emphasizes the openness observed in Indian culture during his travels through Delhi, leading to profound conversations and interactions. He believes that eyes often reveal more than words, suggesting a deeper understanding of human nature lies beneath surface-level expressions.
#
# **Travel Experiences in India**
# The author describes his time in India as magical, highlighting the chaotic yet harmonious traffic conditions reminiscent of swarms of fish moving in unison. This experience is compared to a perfectly tuned orchestra, showcasing the complexity and beauty of Indian life. The author expresses interest in future travels with friends across various regions of India.
#
# **Introduction to "Siddhartha" by Herman Hesse**
# The book "Siddhartha," written during one of Hesse's most challenging periods, serves as an introduction to Eastern philosophical traditions for the author. It was influenced by Hesse’s exploration into Hindu and Buddhist texts like the "Upanishads" and the "Bhagavad Gita." The novel reflects Hesse's personal journey towards healing his fractured psyche through writing.
#
# **Themes in "Siddhartha"**
# "Siddhartha," set in ancient India, follows a young man’s quest for meaning beyond conventional wisdom. Key themes include the illusion of linear time and the interconnectedness of all life experiences. The author draws parallels between these ideas and personal revelations about the nature of reality.
#
# **Lessons from "Siddhartha"**
# The book teaches that true understanding comes not through rejection but through complete immersion in life's experiences, both positive and negative. It emphasizes the distinction between knowledge (which can be taught) and wisdom (gained through direct experience). The author highlights a pivotal moment where Siddhartha asserts his skills: thinking, waiting, and fasting, which symbolize mental clarity, patience, and self-reliance.
#
# **Other Works by Hesse**
# The author recommends other works by Hesse, such as "Demian," "Steppenwolf," and "The Glass Bead Game," each suited for different stages of life. He particularly values "Siddhartha" for its enduring relevance during personal crises.
#
# **Conclusion**
# The context concludes with a quote from the "Bhagavad Gita," emphasizing unity and impartiality in viewing all beings, reflecting themes of interconnectedness and wisdom explored throughout the text. The author thanks his audience and expresses hope for future interactions.

# %%
import ollama

prompt = (
    "==== INSTRUCTIONS ===="
    "Integrate the above provided text from various SubContext into a unified, coherent REPORT BODY suitable for publication. \n"
    "This REPORT BODY will be part of a larger report, include only the main body divided into suitable main sections and subsections without any introduction or conclusion section. \n"
    "Ensure that the combined summary: \n"
    "	1.	Maintains Logical Flow: Arrange the content so that ideas transition smoothly, preserving the original meaning and context. \n"
    "	2.	There should NOT be any duplicate topics or subtopics. \n"
    "	3.	Ensures Clarity: Eliminate redundant information, focusing on delivering a clear narrative. \n"
    "	4.	Adheres to Publication Standards: Format the summary appropriately, using paragraph form and ensuring it meets the conventions of professional writing. \n"
    "   5.  Using bullet points only where appropriate.  \n"
    "   6.  As already mentioned you should NOT have an Introduction or a Conclusion section\n"
    "\n"
    "Avoid introducing external information not present in the original segments. The final report body should be comprehensive, providing readers with a clear understanding of the combined content."
)

system_prompt = (
    "You are an AI critical thinker research assistant. Your sole purpose is to write well written, critically acclaimed,"
     "objective and structured reports on given text. \n"
     "The reports you create are well-structured, informative, in-depth, and include facts and numbers if available.\n"
     "The reports should provide a well-structured framework, including the main sections, subsections, and key points to be covered.\n"
     "Use markdown syntax and follow the APA format. \n"
     "Always respond in english language (en)."
)
# Generate a response using the 'llama3.2' model
main_body = ollama.generate(
    model='summary-assistant',
    prompt=f"{concatenated_content}\n{prompt}",
    system=system_prompt
)
main_body_text = main_body.get('response')
print(main_body_text)
# Out:
# ## Leadership Philosophy and Spiritual Practices
#
# ### Early Life and Upbringing
#
# Narendra Modi was born into a modest family in Vadnagar, Gujarat, where he grew up in extreme poverty but found joy and contentment in simple pleasures. His father's discipline and early morning routines, along with his mother’s values of service and cleanliness, deeply influenced him. The rich cultural heritage of Vadnagar, dating back 2800 years, instilled a sense of curiosity about history and tradition that later shaped Modi’s worldview.
#
# ### Spiritual Journey
#
# Modi’s spiritual journey began at an early age, heavily influenced by the teachings of Swami Vivekananda and other Indian philosophers. At 17, he embarked on a two-year pilgrimage to the Himalayas where he lived minimally, often sleeping outdoors without shelter. This period was marked by intense self-exploration and physical endurance, which strengthened his inner resolve.
#
# ### Influence of Spiritual Leaders
#
# Modi formed a deep bond with Swami Atmasthananda Ji, who guided him towards service rather than monasticism. He also spent time with various saints who instilled in him a sense of purpose and dedication to serving society. His spiritual practices include fasting for extended periods, which he views as a form of self-discipline and introspection.
#
# ### Leadership Philosophy
#
# Modi’s leadership philosophy is rooted in his belief that India's strength lies not just in its leaders but in the collective spirit of 1.4 billion Indians and thousands of years of cultural heritage. He emphasizes peace and harmony, drawing on legacies like those of Gautama Buddha and Mahatma Gandhi.
#
# ### Decision-Making Process
#
# Modi’s decision-making process is multifaceted:
# - **Ground-Level Experience**: Extensive firsthand knowledge of grassroots issues.
# - **No Baggage**: Decisions are free from personal biases or historical constraints.
# - **Country First**: Ensuring decisions do not harm the nation.
# - **Gandhian Wisdom**: Considering how actions affect the poorest citizens.
# - **Well-Connected Network**: Insights from various sources, maintaining a learner’s mindset.
#
# ### Handling Crisis: COVID Response
#
# During the pandemic, Modi resisted global pressures to spend excessively or print more currency. Instead, he focused on ensuring no one went hungry and maintained social stability. This approach led India to avoid severe inflation post-COVID and emerge as a rapidly growing economy.
#
# ## Governance and Reforms
#
# ### Significant Reforms
#
# Since his tenure began in 2014, Modi has implemented significant reforms:
# - **Direct Benefit Transfer (DBT)**: Removed over a hundred million fake or duplicate names from government welfare schemes, saving nearly ₹3 trillion.
# - **Government e-Marketplace (GeM) Portal**: Enhanced competition and quality while reducing unnecessary compliances.
#
# ### Relationship with China
#
# Modi discusses his friendship with Chinese President Xi Jinping and the importance of maintaining strong ties between India and China. Despite recent tensions, he emphasizes that both nations share a deep cultural connection and should focus on dialogue to resolve disputes rather than conflict.
#
# ## International Relations and Diplomacy
#
# ### Relationship with Donald Trump
#
# Modi describes his relationship with former U.S. President Donald Trump as one marked by mutual respect and trust. Despite not meeting physically for years after Trump's first term ended in 2021, their communication remained strong through indirect means. Modi acknowledges Trump’s recent comments about him being an excellent negotiator with humility.
#
# ### Meetings with Other Figures
#
# During a visit to the United States, Modi met several influential individuals including Elon Musk, JD Vance, Tulsi Gabbard, and Vivek Ramaswamy. Discussions ranged from Musk's Doge mission to broader economic and technological advancements.
#
# ## Education System and Exam Stress
#
# Modi advocates for a shift towards actual learning rather than rote memorization in the education system. He emphasizes innovative teaching methods that engage children naturally with numbers and concepts. His "Pariksha Pe Charcha" initiative aims to interact directly with students and address their concerns.
#
# ### Advice to Students
#
# Modi advises students to focus on enhancing skills and finding purpose in their work, regardless of the field they choose. Success comes from dedication and sincerity, and he encourages a growth mindset that values continuous learning and improvement.
#
# ## Spirituality and Science Connection
#
# Prime Minister Modi emphasizes the deep connection between science and spirituality. He cites Srinivasa Ramanujan's belief that his mathematical ideas came from a spiritual source, highlighting how discipline and devotion are integral to achieving great scientific breakthroughs. Knowledge is distinguished from mere information; it evolves through reflection and understanding.
#
# ## Human Interaction and Reading People
#
# Reading people can be challenging due to protective layers that shield their true selves from the outside world. The author emphasizes the openness observed in Indian culture during his travels through Delhi, leading to profound conversations and interactions. He believes that eyes often reveal more than words, suggesting a deeper understanding of human nature lies beneath surface-level expressions.
#
# ## Travel Experiences in India
#
# The author describes his time in India as magical, highlighting the chaotic yet harmonious traffic conditions reminiscent of swarms of fish moving in unison. This experience is compared to a perfectly tuned orchestra, showcasing the complexity and beauty of Indian life. The author expresses interest in future travels with friends across various regions of India.
#
# ## Introduction to "Siddhartha" by Herman Hesse
#
# The book "Siddhartha," written during one of Hesse’s most challenging periods, serves as an introduction to Eastern philosophical traditions for the author. It was influenced by Hesse's exploration into Hindu and Buddhist texts like the "Upanishads" and the "Bhagavad Gita." The novel reflects Hesse’s personal journey towards healing his fractured psyche through writing.
#
# ### Themes in "Siddhartha"
#
# "Siddhartha," set in ancient India, follows a young man’s quest for meaning beyond conventional wisdom. Key themes include the illusion of linear time and the interconnectedness of all life experiences. The author draws parallels between these ideas and personal revelations about the nature of reality.
#
# ### Lessons from "Siddhartha"
#
# The book teaches that true understanding comes not through rejection but through complete immersion in life's experiences, both positive and negative. It emphasizes the distinction between knowledge (which can be taught) and wisdom (gained through direct experience). The author highlights a pivotal moment where Siddhartha asserts his skills: thinking, waiting, and fasting, which symbolize mental clarity, patience, and self-reliance.
#
# ### Other Works by Hesse
#
# The author recommends other works by Hesse, such as "Demian," "Steppenwolf," and "The Glass Bead Game," each suited for different stages of life. He particularly values "Siddhartha" for its enduring relevance during personal crises.
#
# ## Mortality and Hope for the Future
#
# Regarding mortality, Modi believes there is no point fearing death since it is inevitable. Instead, one should embrace life fully and with purpose. He expresses optimism about human civilization's resilience and adaptability to overcome crises and evolve positively.
#
# ## Human Intelligence vs. AI
#
# Modi argues that while technology advances, humans adapt and stay ahead by leveraging their creativity and imagination. Human intelligence remains irreplaceable due to its boundless creativity and the ability to care for others.
#
# ## Spirituality and Meditation
#
# Modi shares his spiritual practices, including chanting mantras like the Gayatri Mantra for enlightenment and peace. He describes meditation as a simple practice of being present in the moment, free from distractions, which he learned through practical techniques such as focusing on rhythmic sounds.

# %%
print(main_body_text)

# %%
prompt = (
    "==== INSTRUCTIONS ===="
    "Review the above provided SubContext and write a short introductions section:\n "
    "	1.	The introduction should be no more than four (4) sentences. \n"
    "	2.	The introduction should capture the attention of the reader so that they will stay engaged with the material. \n"
    "	3.	Do not introduce anything that is not present in the material provided. \n"
)

# Generate a response using the 'llama3.2' model
introduction = ollama.generate(
    model='summary-assistant',
    prompt=f"{concatenated_content}\n{prompt}",
    system=system_prompt
)

introduction_text = introduction.get('response')
print(introduction_text)
# Out:
# Narendra Modi, Prime Minister of India, offers a profound glimpse into his life story, spiritual practices, and leadership philosophy, highlighting his journey from humble beginnings to leading the world's largest democracy. His narrative weaves together deep cultural roots, rigorous self-discipline, and a commitment to peace and service, providing insights into both personal growth and national governance. Through discussions on spirituality, science, education, and international relations, Modi’s approach underscores the importance of ethical decision-making and fostering unity amidst diversity. This exploration also delves into his reflections on literature, particularly Herman Hesse's "Siddhartha," offering a rich tapestry of wisdom and personal development.

# %%
print(concatenated_content)

# %%
prompt = (
    "==== INSTRUCTIONS ===="
    "Review the above provided SubContext and write a short conclusion section:\n "
    "	1.	The conclusion should be no more than three (3) sentences. \n"
    "	2.	The conclusion should capture the reads attention. They should leave with the feeling that they have learned something from the material. \n"
    "	3.	Do not introduce anything that is not present in the material provided. \n"
    "   4.  Always respond in English language (en)."
)

system_prompt = (
    "Respond in english language (en)."
    "You are an AI critical thinker research assistant. Your sole purpose is to write well written, critically acclaimed,"
     "objective and structured reports on given text. \n"
     "The reports you create are well-structured, informative, in-depth, and include facts and numbers if available.\n"
     "The reports should provide a well-structured framework, including the main sections, subsections, and key points to be covered.\n"
     "Use markdown syntax and follow the APA format. \n"
)


conclusion = ollama.generate(
    model='llama3.3:latest',
    prompt=f"{concatenated_content}\n{prompt}",
    system=system_prompt,
    options={'temperature':0.5}
)

conclusion_text = conclusion.get('response')
print(conclusion_text)
# Out:
# In conclusion, the exploration of human interaction, travel experiences, and literary reflections, particularly through Herman Hesse's "Siddhartha," offers profound insights into the nature of reality, wisdom, and personal growth. Through these discussions, readers are invited to embrace a deeper understanding of themselves and the world around them, fostering a sense of unity and interconnectedness. Ultimately, this journey of discovery encourages readers to approach life with an open heart and mind, valuing the wisdom that can be gleaned from both Eastern philosophical traditions and personal experiences.

# %%
draft_report = (
    "==== INTRODUCTION ==== \n"
    f"{introduction_text} \n\n"
    "==== REPORT BODY ==== \n"
    f"{main_body_text} \n\n"
    "==== CONCLUSION ==== \n"
    f"{conclusion_text}"
)



prompt = (
    "==== INSTRUCTIONS ===="
    "Review the above provided Sections INTRODUCTION, REPORT BODY, CONCLUSION and integrate then into the final professional report:\n "
    "	1.	Adhere to all Markdown coding rules \n"
    "	2.	Create an Introduction section by adding the INTRODUCTION context \n"
    "	3.	Review REPORT BODY and remove any introduction or conclusion sections. \n"
    "   4.  Review REPORT BODY for consistency do NOT remove any detail already provided. \n"
    "	5.	Create an Conclusion section by adding the CONCLUSION context \n"
    "   6.  Double check that there is only one Introduction section and one Conclusion section in the report."
)

system_prompt = (
    "You are a copywriting editor specializing in refining and polishing pre-existing documents to prepare them for publication. \n"
    "You are an expert in using Markdown. \n"
)

# Generate a response using the 'llama3.2' model
final_report = ollama.generate(
    model='summary-assistant',
    prompt=f"{draft_report}\n{prompt}",
    system=system_prompt
)

# Print the generated response
print(final_report.get('response'))
# Out:
# # Narendra Modi: A Journey from Humble Beginnings to Leadership
#
# ## Introduction
#
# Narendra Modi, Prime Minister of India, offers a profound glimpse into his life story, spiritual practices, and leadership philosophy, highlighting his journey from humble beginnings to leading the world's largest democracy. His narrative weaves together deep cultural roots, rigorous self-discipline, and a commitment to peace and service, providing insights into both personal growth and national governance. Through discussions on spirituality, science, education, and international relations, Modi’s approach underscores the importance of ethical decision-making and fostering unity amidst diversity. This exploration also delves into his reflections on literature, particularly Herman Hesse's "Siddhartha," offering a rich tapestry of wisdom and personal development.
#
# ## Leadership Philosophy and Spiritual Practices
#
# ### Early Life and Upbringing
#
# Narendra Modi was born into a modest family in Vadnagar, Gujarat, where he grew up in extreme poverty but found joy and contentment in simple pleasures. His father's discipline and early morning routines, along with his mother’s values of service and cleanliness, deeply influenced him. The rich cultural heritage of Vadnagar, dating back 2800 years, instilled a sense of curiosity about history and tradition that later shaped Modi’s worldview.
#
# ### Spiritual Journey
#
# Modi’s spiritual journey began at an early age, heavily influenced by the teachings of Swami Vivekananda and other Indian philosophers. At 17, he embarked on a two-year pilgrimage to the Himalayas where he lived minimally, often sleeping outdoors without shelter. This period was marked by intense self-exploration and physical endurance, which strengthened his inner resolve.
#
# ### Influence of Spiritual Leaders
#
# Modi formed a deep bond with Swami Atmasthananda Ji, who guided him towards service rather than monasticism. He also spent time with various saints who instilled in him a sense of purpose and dedication to serving society. His spiritual practices include fasting for extended periods, which he views as a form of self-discipline and introspection.
#
# ### Leadership Philosophy
#
# Modi’s leadership philosophy is rooted in his belief that India's strength lies not just in its leaders but in the collective spirit of 1.4 billion Indians and thousands of years of cultural heritage. He emphasizes peace and harmony, drawing on legacies like those of Gautama Buddha and Mahatma Gandhi.
#
# ### Decision-Making Process
#
# Modi’s decision-making process is multifaceted:
# - **Ground-Level Experience**: Extensive firsthand knowledge of grassroots issues.
# - **No Baggage**: Decisions are free from personal biases or historical constraints.
# - **Country First**: Ensuring decisions do not harm the nation.
# - **Gandhian Wisdom**: Considering how actions affect the poorest citizens.
# - **Well-Connected Network**: Insights from various sources, maintaining a learner’s mindset.
#
# ### Handling Crisis: COVID Response
#
# During the pandemic, Modi resisted global pressures to spend excessively or print more currency. Instead, he focused on ensuring no one went hungry and maintained social stability. This approach led India to avoid severe inflation post-COVID and emerge as a rapidly growing economy.
#
# ## Governance and Reforms
#
# ### Significant Reforms
#
# Since his tenure began in 2014, Modi has implemented significant reforms:
# - **Direct Benefit Transfer (DBT)**: Removed over a hundred million fake or duplicate names from government welfare schemes, saving nearly ₹3 trillion.
# - **Government e-Marketplace (GeM) Portal**: Enhanced competition and quality while reducing unnecessary compliances.
#
# ### Relationship with China
#
# Modi discusses his friendship with Chinese President Xi Jinping and the importance of maintaining strong ties between India and China. Despite recent tensions, he emphasizes that both nations share a deep cultural connection and should focus on dialogue to resolve disputes rather than conflict.
#
# ## International Relations and Diplomacy
#
# ### Relationship with Donald Trump
#
# Modi describes his relationship with former U.S. President Donald Trump as one marked by mutual respect and trust. Despite not meeting physically for years after Trump's first term ended in 2021, their communication remained strong through indirect means. Modi acknowledges Trump’s recent comments about him being an excellent negotiator with humility.
#
# ### Meetings with Other Figures
#
# During a visit to the United States, Modi met several influential individuals including Elon Musk, JD Vance, Tulsi Gabbard, and Vivek Ramaswamy. Discussions ranged from Musk's Doge mission to broader economic and technological advancements.
#
# ## Education System and Exam Stress
#
# Modi advocates for a shift towards actual learning rather than rote memorization in the education system. He emphasizes innovative teaching methods that engage children naturally with numbers and concepts. His "Pariksha Pe Charcha" initiative aims to interact directly with students and address their concerns.
#
# ### Advice to Students
#
# Modi advises students to focus on enhancing skills and finding purpose in their work, regardless of the field they choose. Success comes from dedication and sincerity, and he encourages a growth mindset that values continuous learning and improvement.
#
# ## Spirituality and Science Connection
#
# Prime Minister Modi emphasizes the deep connection between science and spirituality. He cites Srinivasa Ramanujan's belief that his mathematical ideas came from a spiritual source, highlighting how discipline and devotion are integral to achieving great scientific breakthroughs. Knowledge is distinguished from mere information; it evolves through reflection and understanding.
#
# ## Human Interaction and Reading People
#
# Reading people can be challenging due to protective layers that shield their true selves from the outside world. The author emphasizes the openness observed in Indian culture during his travels through Delhi, leading to profound conversations and interactions. He believes that eyes often reveal more than words, suggesting a deeper understanding of human nature lies beneath surface-level expressions.
#
# ## Travel Experiences in India
#
# The author describes his time in India as magical, highlighting the chaotic yet harmonious traffic conditions reminiscent of swarms of fish moving in unison. This experience is compared to a perfectly tuned orchestra, showcasing the complexity and beauty of Indian life. The author expresses interest in future travels with friends across various regions of India.
#
# ## Introduction to "Siddhartha" by Herman Hesse
#
# The book "Siddhartha," written during one of Hesse’s most challenging periods, serves as an introduction to Eastern philosophical traditions for the author. It was influenced by Hesse's exploration into Hindu and Buddhist texts like the "Upanishads" and the "Bhagavad Gita." The novel reflects Hesse’s personal journey towards healing his fractured psyche through writing.
#
# ### Themes in "Siddhartha"
#
# "Siddhartha," set in ancient India, follows a young man’s quest for meaning beyond conventional wisdom. Key themes include the illusion of linear time and the interconnectedness of all life experiences. The author draws parallels between these ideas and personal revelations about the nature of reality.
#
# ### Lessons from "Siddhartha"
#
# The book teaches that true understanding comes not through rejection but through complete immersion in life's experiences, both positive and negative. It emphasizes the distinction between knowledge (which can be taught) and wisdom (gained through direct experience). The author highlights a pivotal moment where Siddhartha asserts his skills: thinking, waiting, and fasting, which symbolize mental clarity, patience, and self-reliance.
#
# ### Other Works by Hesse
#
# The author recommends other works by Hesse, such as "Demian," "Steppenwolf," and "The Glass Bead Game," each suited for different stages of life. He particularly values "Siddhartha" for its enduring relevance during personal crises.
#
# ## Mortality and Hope for the Future
#
# Regarding mortality, Modi believes there is no point fearing death since it is inevitable. Instead, one should embrace life fully and with purpose. He expresses optimism about human civilization's resilience and adaptability to overcome crises and evolve positively.
#
# ## Human Intelligence vs. AI
#
# Modi argues that while technology advances, humans adapt and stay ahead by leveraging their creativity and imagination. Human intelligence remains irreplaceable due to its boundless creativity and the ability to care for others.
#
# ## Spirituality and Meditation
#
# Modi shares his spiritual practices, including chanting mantras like the Gayatri Mantra for enlightenment and peace. He describes meditation as a simple practice of being present in the moment, free from distractions, which he learned through practical techniques such as focusing on rhythmic sounds.
#
# # Conclusion
#
# In conclusion, the exploration of human interaction, travel experiences, and literary reflections, particularly through Herman Hesse's "Siddhartha," offers profound insights into the nature of reality, wisdom, and personal growth. Through these discussions, readers are invited to embrace a deeper understanding of themselves and the world around them, fostering a sense of unity and interconnectedness. Ultimately, this journey of discovery encourages readers to approach life with an open heart and mind, valuing the wisdom that can be gleaned from both Eastern philosophical traditions and personal experiences.

# %%
with open('final_report.txt', 'w', encoding='utf-8') as file:
    file.write(final_report.get('response'))

# %%
with open('final_report.txt', 'r', encoding='utf-8') as file:
    final_report_text = file.read()

# %%
import markdown2
from weasyprint import HTML

def markdown_to_pdf_weasyprint(markdown_content, output_pdf_path):
    # Convert Markdown to HTML
    html_content = markdown2.markdown(markdown_content)
    
    # Convert HTML to PDF
    HTML(string=html_content).write_pdf(output_pdf_path)

# Example usage
markdown_content = """
# Sample Markdown

This is a sample Markdown content to demonstrate conversion to PDF.

## Features

- Easy to use
- Lightweight
- Customizable
"""

output_pdf_path = 'output_weasyprint.pdf'
markdown_to_pdf_weasyprint(final_report_text, output_pdf_path)
print(f'PDF generated successfully at {output_pdf_path}')
# Out:
# PDF generated successfully at output_weasyprint.pdf

# %%
from checkpoint import set_checkpoint_directory,checkpoint
set_checkpoint_directory('.')
@checkpoint('test')
def test_call():
    print("This is a test!")

test_call()
# Out:
# Skipping 'test_call' as checkpoint 'test' exists.
